# %%
### Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
sns.set(rc = {'figure.figsize':(15,8)})

# %%
### Function to plot graphs
def quadPlot(fileName:str, title:str='Default Title', maxDim:int=1600):
    dataframe = pd.read_csv(f"./results/{fileName}")
    dataframe = dataframe[dataframe["dimension"]<maxDim]
    QuadPlotObj = sns.FacetGrid(dataframe, col='queue', row='graphInput',height=5)
    QuadPlotObj.map(sns.scatterplot, "edges", "time")
    QuadPlotObj.fig.subplots_adjust(top=0.92)
    QuadPlotObj.fig.suptitle(title)

# %%
### Compare Question Objective
def naiveCompare(fileName:str, title:str="Naive Default Title", maxDim:int=1600):
    dataframe = pd.read_csv(f"./results/{fileName}")
    dataframe = dataframe[(dataframe["dimension"] < maxDim) & (((dataframe["queue"]=="array") & (dataframe["graphInput"]=="adjMatrix")) | ((dataframe["queue"]=="heap") & (dataframe["graphInput"]=="adjList")))]
    fig = sns.scatterplot(data=dataframe, x="edges", y="time", hue="graphInput", style="queue")
    fig.set(title=title)

# %%
def compPlot(dataframe, col:str, title:str="Default title"):
    compPlot = sns.FacetGrid(dataframe, col=col, height=8, hue="graphInput", legend_out=True)
    compPlot.map_dataframe(sns.scatterplot, "edges", "time")
    compPlot.fig.subplots_adjust(top=0.92)
    compPlot.fig.suptitle(title)
    compPlot.add_legend()

# %%
quadPlot(fileName="compareAllVar.csv", title="Average Case")

# %%
quadPlot(fileName="compareAllWeighted.csv", title="Fully Connected Graphs")

# %%
quadPlot(fileName="compareAllNonWeighted.csv", title="Non Weighted Partially Connected Graphs")

# %%
naiveCompare(fileName="compareAllVar.csv", title="Average Case")

# %%
naiveCompare(fileName="compareAllWeighted.csv", title="Fully Connected Graphs")

# %%
naiveCompare(fileName="compareAllNonWeighted.csv", title="Non Weighted Partically Connected Graphs")

# %%
fullConDF = pd.read_csv("./results/compareAllWeighted.csv")
fullConDF = fullConDF[((fullConDF["dimension"] < 1600) & ((fullConDF["queue"]=="array") & (fullConDF["graphInput"]=="adjMatrix")) | ((fullConDF["queue"]=="heap") & (fullConDF["graphInput"]=="adjList")))]
fullConDF["case"]=["Fully Connected"] * fullConDF.shape[0]
fullConDF
# Out:
#        dimension    edges  isDirectional  minWeight  maxWeight  queue  \
# 0            100     4950          False          1         50   heap
# 3            100     4950          False          1         50  array
# 4            110     5995          False          1         50   heap
# 7            110     5995          False          1         50  array
# 8            120     7140          False          1         50   heap
# ...          ...      ...            ...        ...        ...    ...
# 34851       1421  1008910          False          1         50  array
# 34852       1452  1053426          False          1         50   heap
# 34855       1452  1053426          False          1         50  array
# 34856       1545  1192740          False          1         50   heap
# 34859       1545  1192740          False          1         50  array
#
#       graphInput         time             case
# 0        adjList     6.201029  Fully Connected
# 3      adjMatrix     9.161949  Fully Connected
# 4        adjList     7.336855  Fully Connected
# 7      adjMatrix    11.276007  Fully Connected
# 8        adjList     8.260965  Fully Connected
# ...          ...          ...              ...
# 34851  adjMatrix  2244.776011  Fully Connected
# 34852    adjList   743.897915  Fully Connected
# 34855  adjMatrix  2343.557835  Fully Connected
# 34856    adjList   787.813902  Fully Connected
# 34859  adjMatrix  2679.437876  Fully Connected
#
# [17430 rows x 9 columns]

# %%
ParConDF = pd.read_csv("./results/compareAllNonWeighted.csv")
ParConDF = ParConDF[((ParConDF["dimension"] < 1600) & ((ParConDF["queue"]=="array") & (ParConDF["graphInput"]=="adjMatrix")) | ((ParConDF["queue"]=="heap") & (ParConDF["graphInput"]=="adjList")))]
ParConDF["case"]=["Partially Connected"] * ParConDF.shape[0]
ParConDF
# Out:
#        dimension   edges  isDirectional  minWeight  maxWeight  queue  \
# 0            100    2555          False          0          1   heap
# 3            100    2555          False          0          1  array
# 4            110    3001          False          0          1   heap
# 7            110    3001          False          0          1  array
# 8            120    3621          False          0          1   heap
# ...          ...     ...            ...        ...        ...    ...
# 35103        579   83629          False          0          1   heap
# 35106        579   83629          False          0          1  array
# 35107        622   96636          False          0          1   heap
# 35110        622   96636          False          0          1  array
# 35111        688  117944          False          0          1   heap
#
#       graphInput        time                 case
# 0        adjList    6.994963  Partially Connected
# 3      adjMatrix    6.636143  Partially Connected
# 4        adjList    6.114006  Partially Connected
# 7      adjMatrix    3.365993  Partially Connected
# 8        adjList    7.058144  Partially Connected
# ...          ...         ...                  ...
# 35103    adjList  155.711174  Partially Connected
# 35106  adjMatrix   74.719906  Partially Connected
# 35107    adjList  183.117151  Partially Connected
# 35110  adjMatrix   84.717035  Partially Connected
# 35111    adjList  229.887962  Partially Connected
#
# [17556 rows x 9 columns]

# %%
bothDF = pd.concat([fullConDF, ParConDF])
bothDF
# Out:
#        dimension   edges  isDirectional  minWeight  maxWeight  queue  \
# 0            100    4950          False          1         50   heap
# 3            100    4950          False          1         50  array
# 4            110    5995          False          1         50   heap
# 7            110    5995          False          1         50  array
# 8            120    7140          False          1         50   heap
# ...          ...     ...            ...        ...        ...    ...
# 35103        579   83629          False          0          1   heap
# 35106        579   83629          False          0          1  array
# 35107        622   96636          False          0          1   heap
# 35110        622   96636          False          0          1  array
# 35111        688  117944          False          0          1   heap
#
#       graphInput        time                 case
# 0        adjList    6.201029      Fully Connected
# 3      adjMatrix    9.161949      Fully Connected
# 4        adjList    7.336855      Fully Connected
# 7      adjMatrix   11.276007      Fully Connected
# 8        adjList    8.260965      Fully Connected
# ...          ...         ...                  ...
# 35103    adjList  155.711174  Partially Connected
# 35106  adjMatrix   74.719906  Partially Connected
# 35107    adjList  183.117151  Partially Connected
# 35110  adjMatrix   84.717035  Partially Connected
# 35111    adjList  229.887962  Partially Connected
#
# [34986 rows x 9 columns]

# %%
compPlot(dataframe=bothDF, col="case", title="Comparing graphs")

# %%
crossOver = pd.read_csv("./results/compareCrossOver.csv")
crossOver = crossOver[crossOver["maxWeight"]!=0]
crossOver = crossOver[((crossOver["queue"] == "array") & (crossOver["graphInput"]=="adjMatrix")) | ((crossOver["queue"]=="heap") & (crossOver["graphInput"]=="adjList"))]
crossOver["algo"] = [""] * crossOver.shape[0]

crossOver
# Out:
#       dimension   edges  isDirectional  minWeight  maxWeight  queue  \
# 4           700  122685          False          0          1   heap
# 7           700  122685          False          0          1  array
# 8           700  162889          False          0          2   heap
# 11          700  162889          False          0          2  array
# 12          700  183445          False          0          3   heap
# ...         ...     ...            ...        ...        ...    ...
# 2255        700  163452          False          0          2  array
# 2256        700  183534          False          0          3   heap
# 2259        700  183534          False          0          3  array
# 2260        700  195941          False          0          4   heap
# 2263        700  195941          False          0          4  array
#
#      graphInput        time algo
# 4       adjList  220.798969
# 7     adjMatrix  103.745937
# 8       adjList  166.563749
# 11    adjMatrix  154.160261
# 12      adjList  159.056902
# ...         ...         ...  ...
# 2255  adjMatrix  155.076265
# 2256    adjList  155.255079
# 2259  adjMatrix  192.791224
# 2260    adjList  156.575918
# 2263  adjMatrix  221.474171
#
# [1108 rows x 9 columns]

# %%
sns.scatterplot(data=crossOver, x="edges", y="time", hue="queue", style="graphInput")
# Out:
# <AxesSubplot:xlabel='edges', ylabel='time'>
