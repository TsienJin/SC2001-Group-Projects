# %%
### Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
sns.set(rc = {'figure.figsize':(15,8)})

# %%
### Loading all data
compareAllVar = pd.read_csv("./results/compareAllVar.csv")
compareAllWeighted = pd.read_csv("./results/compareAllWeighted.csv")
compareAllNonWeighted = pd.read_csv("./results/compareAllNonWeighted.csv")

dataframe = pd.concat([compareAllVar, compareAllWeighted, compareAllNonWeighted])
dataframe
# Out:
#        dimension   edges  isDirectional  minWeight  maxWeight  queue  \
# 0            100    4847          False          0         50   heap
# 1            100    4847          False          0         50   heap
# 2            100    4847          False          0         50  array
# 3            100    4847          False          0         50  array
# 4            110    5886          False          0         50   heap
# ...          ...     ...            ...        ...        ...    ...
# 35107        622   96636          False          0          1   heap
# 35108        622   96636          False          0          1   heap
# 35109        622   96636          False          0          1  array
# 35110        622   96636          False          0          1  array
# 35111        688  117944          False          0          1   heap
#
#       graphInput        time
# 0        adjList    6.683826
# 1      adjMatrix    8.370876
# 2        adjList    8.113861
# ...

# %%
sns.scatterplot(data=dataframe, x="dimension", y="edges", hue="minWeight", style="maxWeight")
# Out:
# <AxesSubplot:xlabel='dimension', ylabel='edges'>
